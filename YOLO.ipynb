# %%
from ultralytics import YOLO #importa a classe YOLO da biblioteca ultralytics

model = YOLO("yolov8m.pt") #carrega o modelo pré-treinado YOLOv8m


model.train(data='./data/data.yaml',
            epochs=10, imgsz=640, batch=16) #inicia o treinamento do modelo em 10 épocas, com as imagens em tamanho de 640x640 e em 16 batches
# Out:
# Ultralytics 8.3.152 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
#importa funções para exibir imagens
from IPython.display import Image, display

#exibe a imagem do gráfico de resultados do treinamento gerada pelo YOLOv8
display(Image(filename='runs/detect/train/results.png'))

# %%
#importa as bibliotecas necessárias
import cv2
import matplotlib.pyplot as plt
import easyocr
from ultralytics import YOLO

#função para detectar a imagem e    
def detect_and_ocr_yolo(image_path, model, reader, score_threshold=0.5):
    #carrega a imagem com OpenCV
    image = cv2.imread(image_path)
    if image is None:
        print(f"Erro ao carregar a imagem: {image_path}")
        return

    #faz a detecção com YOLO
    results = model(image)

    #copia da imagem para plotar depois
    img_plot = cv2.cvtColor(image.copy(), cv2.COLOR_BGR2RGB)

    #itera sobre os resultados e aplica OCR nas caixas com score maior que o threshold
    for result in results:
        for box in result.boxes:
            score = box.conf.item()
            if score < score_threshold:
                continue

            x1, y1, x2, y2 = map(int, box.xyxy[0])
            cropped = image[y1:y2, x1:x2]

            #OCR na região da placa
            ocr_result = reader.readtext(cropped)

            #mostrar texto e confiança
            print("Placa detectada:")
            for (bbox, text, prob) in ocr_result:
                print(f"  Texto: {text} (confiança: {prob:.2f})")

            #sesenhar box na imagem
            cv2.rectangle(img_plot, (x1, y1), (x2, y2), (255, 0, 0), 2)

            #colocar o texto do OCR na imagem
            y_text = y1 - 10 if y1 - 10 > 10 else y1 + 10
            for (bbox, text, prob) in ocr_result:
                cv2.putText(img_plot, f'{text} ({prob:.2f})', (x1, y_text),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 0), 2)
                y_text += 20

    #mostrar a imagem com as caixas e textos
    plt.figure(figsize=(12, 8))
    plt.imshow(img_plot)
    plt.axis('off')
    plt.title("Detecção + OCR com YOLO e EasyOCR")
    plt.show()

# %%
modelYolo = YOLO("runs/detect/train2/weights/best.pt")
reader = easyocr.Reader(['pt'], gpu=True)

detect_and_ocr_yolo("./assets/antiga.png", modelYolo, reader)
# Out:
# 0: 384x640 1 placa, 30.9ms
# Speed: 3.6ms preprocess, 30.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Placa detectada:
#   Texto: U G (confiança: 0.79)
#   Texto: 633e (confiança: 0.47)

# %%
detect_and_ocr_yolo("./assets/antiga1.png", modelYolo, reader)
# Out:
# 0: 384x640 1 placa, 25.3ms
# Speed: 3.7ms preprocess, 25.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Placa detectada:
#   Texto: AYrs49 (confiança: 0.08)

# %%
detect_and_ocr_yolo("./assets/mercosul.png", modelYolo, reader)
# Out:
# 0: 320x640 2 placas, 23.7ms
# Speed: 2.8ms preprocess, 23.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
# Placa detectada:
# Placa detectada:
#   Texto: 50 (confiança: 0.93)

# %%
detect_and_ocr_yolo("./assets/teste.jpg", modelYolo, reader)
# Out:
# 0: 640x320 1 placa, 54.1ms
# Speed: 3.8ms preprocess, 54.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 320)
# Placa detectada:
#   Texto: '7337 (confiança: 0.98)
#   Texto: Gdb; (confiança: 0.37)
